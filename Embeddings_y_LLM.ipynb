# %%
# Instalación de embedder (Gemini) y un almacenador de vectores (Chroma)
# !pip install -U -q google-generativeai
# !pip install -q chromadb
# !pip install -q openai

# %%
import textwrap
import numpy as np
import pandas as pd
from IPython.display import Markdown
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings

from google.colab import userdata
import os
import google.generativeai as genai

# Gemini API
API_KEY=userdata.get('API_KEY_GEMINI')
genai.configure(api_key=API_KEY)

# %%
# Importar data
data = pd.read_excel('/content/dataset_final.xlsx')
data.head()
# Out:
#   Categoría                                           Pregunta  \
# 0     Banca  ¿Cómo cambio mi clave de acceso a la banca en ...
# 1     Banca  ¿Cómo habilito mi tarjeta para compras interna...
# 2   Seguros  ¿Cómo activo la cobertura inmediata en mi segu...
# 3     Banca                 ¿Cómo activo mi tarjeta de débito?
# 4   Seguros  ¿Cómo actualizo mi dirección en mi seguro de h...
#
#                                            Respuesta
# 0  Accede a 'Seguridad' en tu cuenta y redefine t...
# 1  Activa compras internacionales desde la app; ¡...
# 2  Activa la cobertura inmediata llamando a tu as...
# 3  Actívala directamente en un cajero automático ...
# 4  Actualiza tu dirección en la configuración de ...

# %%
# Estructura de datos a vectorizar
data['Pregunta_respuesta'] = data['Pregunta'] + " " + data['Respuesta']
data_text = data['Pregunta_respuesta']
data_text.head()
# Out:
# 0    ¿Cómo cambio mi clave de acceso a la banca en ...
# 1    ¿Cómo habilito mi tarjeta para compras interna...
# 2    ¿Cómo activo la cobertura inmediata en mi segu...
# 3    ¿Cómo activo mi tarjeta de débito? Actívala di...
# 4    ¿Cómo actualizo mi dirección en mi seguro de h...
# Name: Pregunta_respuesta, dtype: object

# %%
# Convertir la columna "Pregunta_Respuesta" en una lista de documentos.
documents = data["Pregunta_respuesta"] # Access the column from the original DataFrame 'data'

# Verificar los primeros documentos
for i, doc in enumerate(documents):  # Mostrar con límie documents[:x], donde x:n° de documentos a visualizar.
    print(f"DOCUMENT{i} = {repr(doc)}\n")
# Out:
# DOCUMENT0 = "¿Cómo cambio mi clave de acceso a la banca en línea? Accede a 'Seguridad' en tu cuenta y redefine tu clave en minutos."
#
# DOCUMENT1 = '¿Cómo habilito mi tarjeta para compras internacionales? Activa compras internacionales desde la app; ¡prepárate para tu próximo viaje!'
#
# DOCUMENT2 = '¿Cómo activo la cobertura inmediata en mi seguro de auto? Activa la cobertura inmediata llamando a tu aseguradora desde el primer día.'
#
# DOCUMENT3 = '¿Cómo activo mi tarjeta de débito? Actívala directamente en un cajero automático o mediante tu aplicación móvil.'
#
# DOCUMENT4 = '¿Cómo actualizo mi dirección en mi seguro de hogar? Actualiza tu dirección en la configuración de tu cuenta bancaria.'
#
# DOCUMENT5 = "¿Cómo puedo cambiar mi dirección registrada en el banco? Actualiza tu dirección fácilmente desde el apartado de 'Perfil' en tu banca digital."
#
# DOCUMENT6 = "¿Cómo modifico los beneficiarios de mi seguro de vida? Actualiza tus beneficiarios en 'Configuración de seguros' dentro de tu banca en línea."
#
# DOCUMENT7 = '¿Cómo actualizo mis datos personales en la banca en línea? Actualiza tus datos personales en la sección de configuración de la app.'
#
# DOCUMENT8 = '¿Qué debo hacer para cerrar una cuenta conjunta? Ambos titulares deben firmar para cerrar cuentas conjuntas. ¡Asegúrate de coordinarlo!'
#
# DOCUMENT9 = '¿Puedo incluir mi seguro de salud en el plan familiar? Amplía tu plan familiar con el seguro de salud para incluir a más dependientes.'
#
# DOCUMENT10 = '¿Puedo incluir a mi cónyuge en mi póliza de salud? Añade a tu cónyuge al seguro enviando una solicitud y los documentos necesarios.'
#
# DOCUMENT11 = "¿Cómo agrego beneficiarios a mi cuenta bancaria? Añade beneficiarios fácilmente en la sección de 'Cuentas y transferencias'."
#
# DOCUMENT12 = '¿Cómo agrego cobertura adicional a mi seguro actual? Añade cobertura extra llamando al banco o a través de su web.'
#
# DOCUMENT13 = '¿Qué documentos necesito para cancelar una cuenta de inversión? Asegúrate de cumplir los requisitos para cerrar cuentas de inversión.'
#
# DOCUMENT14 = '¿Qué ocurre con los saldos pendientes si cierro mi cuenta? Asegúrate de saldar todos los pendientes antes de cerrar la cuenta.'
#
# DOCUMENT15 = '¿Cómo calculo la prima de un seguro para mi auto? Calcula tu prima en línea. ¡Un simulador te dará una estimación al instante!'
#
# DOCUMENT16 = '¿Qué pasos debo seguir para cancelar un seguro de auto? Cancela tu póliza de auto llamando al servicio de atención al cliente.'
#
# DOCUMENT17 = '¿Qué ocurre con mis puntos de recompensa al cerrar una cuenta? Canjea tus puntos acumulados antes de cerrar la cuenta para aprovecharlos.'
#
# DOCUMENT18 = '¿Cómo cierro mi cuenta bancaria? Cierra tu cuenta en una sucursal o solicita el trámite desde la app, si está habilitado.'
#
# DOCUMENT19 = '¿Puedo combinar diferentes seguros en una sola póliza? Combina seguros de auto y hogar para ahorrar; consulta las opciones con tu banco.'
#
# DOCUMENT20 = "¿Cuáles son los pasos para realizar una transferencia internacional? Completa los datos de destino en 'Transferencias internacionales' y confirma con tu clave."
#
# DOCUMENT21 = "¿Cómo configuro alertas personalizadas para mi cuenta? Configura alertas en la sección de 'Notificaciones' para mantenerte al tanto."
#
# DOCUMENT22 = "¿Cómo configuro notificaciones por SMS de movimientos bancarios? Configura alertas para movimientos en la sección de 'Notificaciones' en tu perfil."
#
# DOCUMENT23 = '¿Qué pasos debo seguir para configurar un débito automático? Configura pagos automáticos seleccionando la factura que quieres domiciliar.'
#
# DOCUMENT24 = '¿Puedo cerrar mi cuenta con saldo negativo? Confirma si puedes cubrir el saldo negativo antes del cierre con un pago.'
#
# DOCUMENT25 = '¿Qué beneficios tiene contratar un seguro de auto con cobertura amplia? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT26 = '¿Puedo transferir mi seguro de vida a otro banco? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT27 = '¿Qué ocurre si no renuevo mi seguro de hogar a tiempo? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT28 = '¿Puedo cotizar un seguro de viaje para varios destinos? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT29 = '¿Qué cubre un seguro médico internacional? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT30 = '¿Cómo accedo al reembolso por pérdida de equipaje en un seguro de viaje? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT31 = '¿Qué debo hacer si deseo cambiar de plan de seguro médico? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT32 = '¿Cómo obtengo asesoría sobre los mejores seguros para mi familia? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT33 = '¿Qué pasos debo seguir para solicitar una segunda opinión médica con mi seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT34 = '¿Puedo solicitar una ampliación temporal de mi póliza de auto? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT35 = '¿Qué sucede si deseo cancelar mi seguro antes del plazo contratado? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT36 = '¿Cómo informo sobre un accidente para iniciar un reclamo de seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT37 = '¿Puedo asegurar mi moto junto con mi auto en una sola póliza? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT38 = '¿Qué debo verificar antes de contratar un seguro de responsabilidad civil? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT39 = '¿Cómo obtengo una copia de mi contrato de seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT40 = '¿Qué hago si mi solicitud de seguro ha sido rechazada? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT41 = '¿Qué beneficios ofrecen los seguros escolares? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT42 = '¿Cómo incluyo coberturas adicionales a mi seguro médico? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT43 = '¿Qué opciones existen para seguros de alquiler de viviendas? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT44 = '¿Cómo contrato un seguro de vida sin exámenes médicos? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT45 = '¿Qué beneficios tiene contratar un seguro de auto con cobertura amplia? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT46 = '¿Puedo transferir mi seguro de vida a otro banco? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT47 = '¿Qué ocurre si no renuevo mi seguro de hogar a tiempo? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT48 = '¿Puedo cotizar un seguro de viaje para varios destinos? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT49 = '¿Qué cubre un seguro médico internacional? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT50 = '¿Cómo accedo al reembolso por pérdida de equipaje en un seguro de viaje? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT51 = '¿Qué debo hacer si deseo cambiar de plan de seguro médico? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT52 = '¿Cómo obtengo asesoría sobre los mejores seguros para mi familia? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT53 = '¿Qué pasos debo seguir para solicitar una segunda opinión médica con mi seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT54 = '¿Puedo solicitar una ampliación temporal de mi póliza de auto? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT55 = '¿Qué sucede si deseo cancelar mi seguro antes del plazo contratado? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT56 = '¿Cómo informo sobre un accidente para iniciar un reclamo de seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT57 = '¿Puedo asegurar mi moto junto con mi auto en una sola póliza? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT58 = '¿Qué debo verificar antes de contratar un seguro de responsabilidad civil? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT59 = '¿Cómo obtengo una copia de mi contrato de seguro? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT60 = '¿Qué hago si mi solicitud de seguro ha sido rechazada? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT61 = '¿Qué beneficios ofrecen los seguros escolares? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT62 = '¿Cómo incluyo coberturas adicionales a mi seguro médico? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT63 = '¿Qué opciones existen para seguros de alquiler de viviendas? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT64 = '¿Cómo contrato un seguro de vida sin exámenes médicos? Consulta con tu asesor para obtener detalles específicos.'
#
# DOCUMENT65 = '¿Qué requisitos necesito para solicitar una línea de crédito? Consulta las condiciones de tu línea de crédito en el portal de tu banco.'
#
# DOCUMENT66 = '¿Qué requisitos necesito para solicitar una línea de crédito? Consulta las condiciones de tu línea de crédito en el portal de tu banco.'
#
# DOCUMENT67 = '¿Qué requisitos necesito para solicitar una línea de crédito? Consulta las condiciones de tu línea de crédito en el portal de tu banco.'
#
# DOCUMENT68 = '¿Puedo asegurar mi auto si no tengo licencia? Consulta las condiciones para asegurar un auto sin licencia en el portal.'
#
# DOCUMENT69 = '¿Puedo asegurar mi auto si no tengo licencia? Consulta las condiciones para asegurar un auto sin licencia en el portal.'
#
# DOCUMENT70 = '¿Puedo asegurar mi auto si no tengo licencia? Consulta las condiciones para asegurar un auto sin licencia en el portal.'
#
# DOCUMENT71 = '¿Cuáles son las exclusiones típicas en un seguro de vida? Consulta las exclusiones en el contrato. ¡Es importante estar bien informado!'
#
# DOCUMENT72 = '¿Cuáles son las exclusiones típicas en un seguro de vida? Consulta las exclusiones en el contrato. ¡Es importante estar bien informado!'
#
# DOCUMENT73 = '¿Cuáles son las exclusiones típicas en un seguro de vida? Consulta las exclusiones en el contrato. ¡Es importante estar bien informado!'
#
# DOCUMENT74 = '¿Cómo cancelo un crédito hipotecario? Consulta las opciones para cancelar hipotecas con el asesor de tu banco.'
#
# DOCUMENT75 = '¿Cómo cancelo un crédito hipotecario? Consulta las opciones para cancelar hipotecas con el asesor de tu banco.'
#
# DOCUMENT76 = '¿Cómo cancelo un crédito hipotecario? Consulta las opciones para cancelar hipotecas con el asesor de tu banco.'
#
# DOCUMENT77 = '¿Qué pasa con mis beneficios acumulados al cancelar mi membresía bancaria? Consulta las políticas sobre beneficios acumulados antes de cerrar.'
#
# DOCUMENT78 = '¿Puedo abrir una cuenta compartida con un amigo? Consulta los requisitos para cuentas compartidas y asegúrate de cumplirlos.'
#
# DOCUMENT79 = '¿Qué ocurre con los cheques pendientes al cerrar mi cuenta? Consulta qué ocurre con cheques en proceso antes de iniciar el cierre.'
#
# DOCUMENT80 = '¿Qué ocurre con los cheques pendientes al cerrar mi cuenta? Consulta qué ocurre con cheques en proceso antes de iniciar el cierre.'
#
# DOCUMENT81 = '¿Qué ocurre con los cheques pendientes al cerrar mi cuenta? Consulta qué ocurre con cheques en proceso antes de iniciar el cierre.'
#
# DOCUMENT82 = '¿Puedo asegurar mi mascota a través del banco? Consulta si el banco ofrece seguros para mascotas como parte de sus servicios.'
#
# DOCUMENT83 = '¿Cómo puedo consultar mi saldo bancario? Consulta tu saldo rápidamente desde la app móvil o con un comando por voz si tu banco lo permite.'
#
# DOCUMENT84 = '¿Cómo puedo consultar mi saldo bancario? Consulta tu saldo rápidamente desde la app móvil o con un comando por voz si tu banco lo permite.'
#
# DOCUMENT85 = '¿Cómo puedo consultar mi saldo bancario? Consulta tu saldo rápidamente desde la app móvil o con un comando por voz si tu banco lo permite.'
#
# DOCUMENT86 = '¿Qué debo hacer para cancelar mi tarjeta de crédito? Contacta a atención al cliente y sigue el proceso para cancelar tu tarjeta.'
#
# DOCUMENT87 = '¿Qué debo hacer para cancelar mi tarjeta de crédito? Contacta a atención al cliente y sigue el proceso para cancelar tu tarjeta.'
#
# DOCUMENT88 = '¿Qué debo hacer para cancelar mi tarjeta de crédito? Contacta a atención al cliente y sigue el proceso para cancelar tu tarjeta.'
#
# DOCUMENT89 = '¿Cómo cierro mi cuenta si estoy fuera del país? Contacta a tu banco por teléfono o chat si estás fuera del país.'
#
# DOCUMENT90 = '¿Cómo cierro mi cuenta si estoy fuera del país? Contacta a tu banco por teléfono o chat si estás fuera del país.'
#
# DOCUMENT91 = '¿Cómo cierro mi cuenta si estoy fuera del país? Contacta a tu banco por teléfono o chat si estás fuera del país.'
#
# DOCUMENT92 = '¿Qué hago si mi transferencia bancaria fue rechazada? Contacta al servicio de atención al cliente y solicita una revisión del caso.'
#
# DOCUMENT93 = '¿Cómo se realiza la baja de un seguro de vida? Contacta con tu agente personal o llama al servicio de atención al cliente para la cancelación del seguro de vida.'
#
# DOCUMENT94 = '¿Cómo obtengo un préstamo hipotecario? Contacta con tu banco para más información.'
#
# DOCUMENT95 = '¿Qué opciones de cuentas bancarias ofrece el banco? Contacta con tu banco para más información.'
#
# DOCUMENT96 = '¿Cómo transfiero dinero entre mis propias cuentas? Contacta con tu banco para más información.'
#
# DOCUMENT97 = '¿Cómo abro una cuenta para un menor de edad? Contacta con tu banco para más información.'
#
# DOCUMENT98 = '¿Puedo solicitar un aumento en el límite de mi tarjeta de crédito? Contacta con tu banco para más información.'
#
# DOCUMENT99 = '¿Cómo configuro un PIN para mi tarjeta nueva? Contacta con tu banco para más información.'
#
# DOCUMENT100 = '¿Qué hago si no puedo acceder a la banca en línea? Contacta con tu banco para más información.'
#
# DOCUMENT101 = '¿Cómo cambio el número de teléfono asociado a mi cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT102 = '¿Qué tipos de cuentas ofrecen beneficios por fidelidad? Contacta con tu banco para más información.'
#
# DOCUMENT103 = '¿Cómo puedo dividir un pago entre varias cuentas? Contacta con tu banco para más información.'
#
# DOCUMENT104 = '¿Es posible retirar efectivo sin tarjeta? Contacta con tu banco para más información.'
#
# DOCUMENT105 = '¿Cómo descargo mi historial de transacciones completo? Contacta con tu banco para más información.'
#
# DOCUMENT106 = '¿Qué hago si recibo un mensaje sospechoso del banco? Contacta con tu banco para más información.'
#
# DOCUMENT107 = '¿Puedo abrir una cuenta si soy extranjero? Contacta con tu banco para más información.'
#
# DOCUMENT108 = '¿Qué debo hacer para recibir pagos internacionales? Contacta con tu banco para más información.'
#
# DOCUMENT109 = '¿Cómo puedo solicitar el bloqueo temporal de mi cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT110 = '¿Dónde encuentro los horarios de atención de mi banco? Contacta con tu banco para más información.'
#
# DOCUMENT111 = '¿Cómo gestiono múltiples tarjetas de débito asociadas a una cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT112 = '¿Es posible vincular mi cuenta bancaria a servicios de pago como PayPal? Contacta con tu banco para más información.'
#
# DOCUMENT113 = '¿Qué debo hacer si detecto cargos duplicados en mi tarjeta? Contacta con tu banco para más información.'
#
# DOCUMENT114 = '¿Cómo obtengo un préstamo hipotecario? Contacta con tu banco para más información.'
#
# DOCUMENT115 = '¿Qué opciones de cuentas bancarias ofrece el banco? Contacta con tu banco para más información.'
#
# DOCUMENT116 = '¿Cómo transfiero dinero entre mis propias cuentas? Contacta con tu banco para más información.'
#
# DOCUMENT117 = '¿Cómo abro una cuenta para un menor de edad? Contacta con tu banco para más información.'
#
# DOCUMENT118 = '¿Puedo solicitar un aumento en el límite de mi tarjeta de crédito? Contacta con tu banco para más información.'
#
# DOCUMENT119 = '¿Cómo configuro un PIN para mi tarjeta nueva? Contacta con tu banco para más información.'
#
# DOCUMENT120 = '¿Qué hago si no puedo acceder a la banca en línea? Contacta con tu banco para más información.'
#
# DOCUMENT121 = '¿Cómo cambio el número de teléfono asociado a mi cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT122 = '¿Qué tipos de cuentas ofrecen beneficios por fidelidad? Contacta con tu banco para más información.'
#
# DOCUMENT123 = '¿Cómo puedo dividir un pago entre varias cuentas? Contacta con tu banco para más información.'
#
# DOCUMENT124 = '¿Es posible retirar efectivo sin tarjeta? Contacta con tu banco para más información.'
#
# DOCUMENT125 = '¿Cómo descargo mi historial de transacciones completo? Contacta con tu banco para más información.'
#
# DOCUMENT126 = '¿Qué hago si recibo un mensaje sospechoso del banco? Contacta con tu banco para más información.'
#
# DOCUMENT127 = '¿Puedo abrir una cuenta si soy extranjero? Contacta con tu banco para más información.'
#
# DOCUMENT128 = '¿Qué debo hacer para recibir pagos internacionales? Contacta con tu banco para más información.'
#
# DOCUMENT129 = '¿Cómo puedo solicitar el bloqueo temporal de mi cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT130 = '¿Dónde encuentro los horarios de atención de mi banco? Contacta con tu banco para más información.'
#
# DOCUMENT131 = '¿Cómo gestiono múltiples tarjetas de débito asociadas a una cuenta? Contacta con tu banco para más información.'
#
# DOCUMENT132 = '¿Es posible vincular mi cuenta bancaria a servicios de pago como PayPal? Contacta con tu banco para más información.'
#
# DOCUMENT133 = '¿Qué debo hacer si detecto cargos duplicados en mi tarjeta? Contacta con tu banco para más información.'
#
# DOCUMENT134 = '¿Cómo funcionan los seguros por días para vehículos? Contrata seguros por días para vehículos si necesitas cubrir viajes cortos.'
#
# DOCUMENT135 = '¿Es posible cerrar una cuenta con múltiples titulares? Coordina con los otros titulares para cerrar cuentas conjuntas sin problemas.'
#
# DOCUMENT136 = '¿Cómo cotizo un seguro para mi vehículo? Cotiza tu seguro de auto usando el simulador en la web del banco. ¡Es simple y rápido!'
#
# DOCUMENT137 = '¿Cómo cotizo un seguro para mi vehículo? Cotiza tu seguro de auto usando el simulador en la web del banco. ¡Es simple y rápido!'
#
# DOCUMENT138 = '¿Cómo cotizo un seguro para mi vehículo? Cotiza tu seguro de auto usando el simulador en la web del banco. ¡Es simple y rápido!'
#
# DOCUMENT139 = '¿Cómo cotizo un seguro para mi negocio? Cotiza un seguro empresarial directamente desde la app, en la sección de negocios.'
#
# DOCUMENT140 = '¿Cómo cotizo un seguro para mi negocio? Cotiza un seguro empresarial directamente desde la app, en la sección de negocios.'
#
# DOCUMENT141 = '¿Cómo cotizo un seguro para mi negocio? Cotiza un seguro empresarial directamente desde la app, en la sección de negocios.'
#
# DOCUMENT142 = '¿Qué cubre un seguro de hogar a todo riesgo? Cubre daños a la vivienda y pertenencias por casi cualquier causa, excepto las exclusiones específicas.'
#
# DOCUMENT143 = '¿Qué es un seguro de automóvil a todo riesgo? Cubre daños a tu vehículo y a terceros, así como robos y vandalismo.'
#
# DOCUMENT144 = '¿Qué cubre un seguro de automóvil completo? Cubre daños a tu vehículo, así como daños a terceros y gastos médicos por accidentes.'
#
# DOCUMENT145 = '¿Qué cubre un seguro de responsabilidad civil para empresas? Cubre daños y lesiones a terceros, así como gastos legales en caso de demandas contra la empresa.'
#
# DOCUMENT146 = '¿Qué cubre un seguro de vida accidental? Cubre el fallecimiento accidental y puede pagar un beneficio adicional.'
#
# DOCUMENT147 = '¿Qué cubre un seguro de salud para emergencias? Cubre gastos médicos por emergencias, incluyendo hospitalización y tratamientos urgentes.'
#
# DOCUMENT148 = '¿Qué cubre un seguro de salud para tratamientos médicos? Cubre gastos médicos, hospitalarios y tratamientos necesarios según la póliza.'
#
# DOCUMENT149 = '¿Qué cubre un seguro de salud para maternidad? Cubre gastos relacionados con el embarazo, el parto y cuidados postnatales.'
#
# DOCUMENT150 = '¿Qué pasa si tengo un saldo pendiente al momento de cerrar mi cuenta? Deberá cancelar su saldo pendiente antes de cerrar su cuenta.'
#
# DOCUMENT151 = '¿Qué debo hacer con mi chequera al cerrar mi cuenta? Deberá devolver la chequera a nuestra sucursal al momento de cerrar la cuenta.'
#
# DOCUMENT152 = '¿Cómo puedo cancelar mi seguro de hogar? Debes comunicarte con el servicio al cliente para iniciar el proceso de cancelación de tu seguro de hogar.'
#
# DOCUMENT153 = '¿Cómo puedo cancelar un seguro de viaje? Debes comunicarte con la aseguradora para cancelar tu seguro de viaje antes de la fecha de inicio.'
#
# DOCUMENT154 = '¿Cómo puedo cancelar un seguro de vida? Debes comunicarte con tu aseguradora para iniciar el proceso de cancelación.'
#
# DOCUMENT155 = '¿Cómo puedo cancelar un seguro de automóvil? Debes comunicarte con tu aseguradora para iniciar el proceso de cancelación.'
#
# DOCUMENT156 = '¿Cómo puedo presentar un reclamo por accidente automovilístico? Debes comunicarte con tu aseguradora y proporcionar la información necesaria sobre el accidente.'
#
# DOCUMENT157 = '¿Cómo puedo presentar un reclamo por daños en mi hogar? Debes comunicarte con tu aseguradora y proporcionar la información necesaria sobre los daños.'
#
# DOCUMENT158 = '¿Cómo renuncio a un servicio de débito automático? Desactiva débitos automáticos desde tu perfil bancario antes de renunciar.'
#
# DOCUMENT159 = '¿Cómo renuncio a un servicio de débito automático? Desactiva débitos automáticos desde tu perfil bancario antes de renunciar.'
#
# DOCUMENT160 = '¿Cómo renuncio a un servicio de débito automático? Desactiva débitos automáticos desde tu perfil bancario antes de renunciar.'
#
# DOCUMENT161 = "¿Cómo cancelo servicios adicionales ligados a mi cuenta? Desactiva servicios extra en la sección 'Mi cuenta' antes del cierre."
#
# DOCUMENT162 = '¿Cómo activo mi banca móvil sin ir a la sucursal? Descarga la app del banco y sigue las instrucciones para activar la banca móvil.'
#
# DOCUMENT163 = "¿Cómo obtengo el certificado de cobertura de mi seguro? Descarga tu certificado en la pestaña 'Documentos' dentro de tu banca digital."
#
# DOCUMENT164 = "¿Cómo obtengo el certificado de cobertura de mi seguro? Descarga tu certificado en la pestaña 'Documentos' dentro de tu banca digital."
#
# DOCUMENT165 = "¿Cómo obtengo el certificado de cobertura de mi seguro? Descarga tu certificado en la pestaña 'Documentos' dentro de tu banca digital."
#
# DOCUMENT166 = '¿Cómo puedo solicitar un estado de cuenta mensual? Descarga tus estados de cuenta en PDF desde tu perfil bancario.'
#
# DOCUMENT167 = '¿Cómo puedo solicitar un estado de cuenta mensual? Descarga tus estados de cuenta en PDF desde tu perfil bancario.'
#
# DOCUMENT168 = '¿Cómo puedo solicitar un estado de cuenta mensual? Descarga tus estados de cuenta en PDF desde tu perfil bancario.'
#
# DOCUMENT169 = '¿Qué ocurre con los documentos digitales al cerrar mi cuenta? Descarga y guarda tus documentos digitales antes de finalizar el proceso.'
#
# DOCUMENT170 = '¿Qué beneficios tiene un seguro de educación? Descubre los beneficios educativos de tu seguro en el portal del banco.'
#
# DOCUMENT171 = '¿Qué beneficios tiene un seguro de educación? Descubre los beneficios educativos de tu seguro en el portal del banco.'
#
# DOCUMENT172 = '¿Qué beneficios tiene un seguro de educación? Descubre los beneficios educativos de tu seguro en el portal del banco.'
#
# DOCUMENT173 = '¿Cómo cancelo una transferencia recurrente programada? Detén transferencias recurrentes desde la configuración en tu banca digital.'
#
# DOCUMENT174 = '¿Cómo cancelo una transferencia recurrente programada? Detén transferencias recurrentes desde la configuración en tu banca digital.'
#
# DOCUMENT175 = '¿Cómo cancelo una transferencia recurrente programada? Detén transferencias recurrentes desde la configuración en tu banca digital.'
#
# DOCUMENT176 = '¿Puedo cerrar mi cuenta bancaria en línea desde otro país? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT177 = '¿Qué debo hacer para cancelar un servicio de inversión? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT178 = '¿Cómo renuncio a un fondo mutuo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT179 = '¿Es posible reactivar una cuenta cerrada por error? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT180 = '¿Qué pasa con los intereses acumulados al cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT181 = '¿Puedo cerrar una cuenta bloqueada por actividad sospechosa? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT182 = '¿Qué ocurre con las transferencias pendientes al cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT183 = '¿Cómo cancelo un plan de ahorro automático? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT184 = '¿Qué ocurre con los cobros de membresía al cerrar mi cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT185 = '¿Qué debo hacer si el banco me niega el cierre de una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT186 = '¿Cómo devuelvo una tarjeta de crédito cancelada? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT187 = '¿Es posible cerrar una cuenta conjunta sin el consentimiento de los otros titulares? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT188 = '¿Puedo cerrar mi cuenta si tengo pagos automáticos activos? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT189 = '¿Cómo notifico al banco sobre mi intención de cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT190 = '¿Qué ocurre si intento cerrar una cuenta con saldo negativo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT191 = '¿Cómo renuncio a un préstamo hipotecario antes de tiempo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT192 = '¿Qué pasos seguir para cerrar una cuenta con restricciones legales? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT193 = '¿Es posible transferir fondos de una cuenta cerrada a otra? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT194 = '¿Cómo obtengo un comprobante de cierre de cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT195 = '¿Qué opciones tengo si quiero cancelar una línea de crédito empresarial? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT196 = '¿Puedo cerrar mi cuenta bancaria en línea desde otro país? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT197 = '¿Qué debo hacer para cancelar un servicio de inversión? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT198 = '¿Cómo renuncio a un fondo mutuo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT199 = '¿Es posible reactivar una cuenta cerrada por error? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT200 = '¿Qué pasa con los intereses acumulados al cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT201 = '¿Puedo cerrar una cuenta bloqueada por actividad sospechosa? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT202 = '¿Qué ocurre con las transferencias pendientes al cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT203 = '¿Cómo cancelo un plan de ahorro automático? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT204 = '¿Qué ocurre con los cobros de membresía al cerrar mi cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT205 = '¿Qué debo hacer si el banco me niega el cierre de una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT206 = '¿Cómo devuelvo una tarjeta de crédito cancelada? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT207 = '¿Es posible cerrar una cuenta conjunta sin el consentimiento de los otros titulares? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT208 = '¿Puedo cerrar mi cuenta si tengo pagos automáticos activos? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT209 = '¿Cómo notifico al banco sobre mi intención de cerrar una cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT210 = '¿Qué ocurre si intento cerrar una cuenta con saldo negativo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT211 = '¿Cómo renuncio a un préstamo hipotecario antes de tiempo? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT212 = '¿Qué pasos seguir para cerrar una cuenta con restricciones legales? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT213 = '¿Es posible transferir fondos de una cuenta cerrada a otra? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT214 = '¿Cómo obtengo un comprobante de cierre de cuenta? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT215 = '¿Qué opciones tengo si quiero cancelar una línea de crédito empresarial? Dirígete a tu sucursal para más orientación.'
#
# DOCUMENT216 = '¿Cuánto tiempo toma procesar el cierre de una cuenta bancaria? El cierre puede tardar algunos días; consulta el tiempo estimado con tu banco.'
#
# DOCUMENT217 = '¿Cuánto tiempo toma procesar el cierre de una cuenta bancaria? El cierre puede tardar algunos días; consulta el tiempo estimado con tu banco.'
#
# DOCUMENT218 = '¿Cuánto tiempo toma procesar el cierre de una cuenta bancaria? El cierre puede tardar algunos días; consulta el tiempo estimado con tu banco.'
#
# DOCUMENT219 = '¿Cuál es el periodo de carencia en el seguro de vida? El periodo de carencia para nuestro seguro de vida depende de la modalidad que usted escogió. Consulte nuestra página web o su contrato.'
#
# DOCUMENT220 = '¿Cómo puedo cancelar mi suscripción a un servicio? El proceso para cancelar un servicio dependerá de cuál sea éste. En nuestra web tienes más información, o llama al número de asistencia técnica.'
#
# DOCUMENT221 = '¿Qué debo hacer para renunciar a un producto financiero? El proceso para renunciar a un producto financiero depende del producto en cuestión. Te recomendamos ponerte en contacto con tu asesor personal para iniciar el trámite.'
#
# DOCUMENT222 = '¿Qué cubre el seguro contra accidentes personales? El seguro contra accidentes cubre gastos médicos y compensaciones en casos específicos.'
#
# DOCUMENT223 = '¿Qué cubre el seguro contra accidentes personales? El seguro contra accidentes cubre gastos médicos y compensaciones en casos específicos.'
#
# DOCUMENT224 = '¿Qué cubre el seguro contra accidentes personales? El seguro contra accidentes cubre gastos médicos y compensaciones en casos específicos.'
#
# DOCUMENT225 = '¿Cuánto tiempo tarda el proceso de cierre de una cuenta bancaria? El tiempo de procesamiento para cerrar una cuenta bancaria suele ser de 10 a 15 días hábiles.'
#
# DOCUMENT226 = '¿Cuánto tiempo se tarda en cerrar una cuenta bancaria? El tiempo que tarda el proceso de cierre depende de varios factores, como documentación e información del cliente. Por favor, contacta con tu sucursal.'
#
# DOCUMENT227 = '¿Qué pasa con mis débitos automáticos al cerrar mi cuenta? Elimina débitos automáticos antes de cerrar tu cuenta bancaria.'
#
# DOCUMENT228 = '¿Qué pasa con mis débitos automáticos al cerrar mi cuenta? Elimina débitos automáticos antes de cerrar tu cuenta bancaria.'
#
# DOCUMENT229 = '¿Qué pasa con mis débitos automáticos al cerrar mi cuenta? Elimina débitos automáticos antes de cerrar tu cuenta bancaria.'
#
# DOCUMENT230 = '¿Qué debo hacer en caso de un siniestro? En caso de un siniestro, debes contactarnos inmediatamente a través de nuestro número de teléfono de emergencias para iniciar el proceso de reclamación.'
#
# DOCUMENT231 = "¿Dónde puedo encontrar el SWIFT de mi banco? Encuentra tu código SWIFT en 'Información internacional' o en el contrato de tu cuenta."
#
# DOCUMENT232 = "¿Dónde puedo encontrar el SWIFT de mi banco? Encuentra tu código SWIFT en 'Información internacional' o en el contrato de tu cuenta."
#
# DOCUMENT233 = "¿Dónde puedo encontrar el SWIFT de mi banco? Encuentra tu código SWIFT en 'Información internacional' o en el contrato de tu cuenta."
#
# DOCUMENT234 = "¿Cómo obtengo el número IBAN de mi cuenta? Encuentra tu IBAN en tus extractos bancarios o en la pestaña 'Detalles de cuenta'."
#
# DOCUMENT235 = "¿Cómo obtengo el número IBAN de mi cuenta? Encuentra tu IBAN en tus extractos bancarios o en la pestaña 'Detalles de cuenta'."
#
# DOCUMENT236 = "¿Cómo obtengo el número IBAN de mi cuenta? Encuentra tu IBAN en tus extractos bancarios o en la pestaña 'Detalles de cuenta'."
#
# DOCUMENT237 = '¿Qué es un deducible y cómo afecta mi cobertura? Entiende el impacto del deducible revisando tu contrato de seguro.'
#
# DOCUMENT238 = "¿Qué debo hacer para generar una cartola bancaria? Entra a tu banca online, busca 'Documentos' y descarga tu cartola con un solo clic."
#
# DOCUMENT239 = "¿Qué debo hacer para generar una cartola bancaria? Entra a tu banca online, busca 'Documentos' y descarga tu cartola con un solo clic."
#
# DOCUMENT240 = "¿Qué debo hacer para generar una cartola bancaria? Entra a tu banca online, busca 'Documentos' y descarga tu cartola con un solo clic."
#
# DOCUMENT241 = '¿Cómo solicito el cierre de una cuenta por fallecimiento del titular? Entrega los documentos legales necesarios para cerrar cuentas por fallecimiento.'
#
# DOCUMENT242 = '¿Cómo solicito el cierre de una cuenta por fallecimiento del titular? Entrega los documentos legales necesarios para cerrar cuentas por fallecimiento.'
#
# DOCUMENT243 = '¿Cómo solicito el cierre de una cuenta por fallecimiento del titular? Entrega los documentos legales necesarios para cerrar cuentas por fallecimiento.'
#
# DOCUMENT244 = '¿Cuáles son los pasos para reclamar un seguro de vida? Entrega los documentos necesarios y completa el formulario para recibir tu pago de seguro.'
#
# DOCUMENT245 = '¿Cuáles son los pasos para reclamar un seguro de vida? Entrega los documentos necesarios y completa el formulario para recibir tu pago de seguro.'
#
# DOCUMENT246 = '¿Cuáles son los pasos para reclamar un seguro de vida? Entrega los documentos necesarios y completa el formulario para recibir tu pago de seguro.'
#
# DOCUMENT247 = '¿Cómo renuncio a mi membresía en el banco? Envía una solicitud escrita indicando tu renuncia a la membresía bancaria.'
#
# DOCUMENT248 = '¿Cómo renuncio a mi membresía en el banco? Envía una solicitud escrita indicando tu renuncia a la membresía bancaria.'
#
# DOCUMENT249 = '¿Cómo renuncio a mi membresía en el banco? Envía una solicitud escrita indicando tu renuncia a la membresía bancaria.'
#
# DOCUMENT250 = '¿Qué sucede si no devuelvo el medio de pago al cancelar el servicio? Es importante que devuelvas los elementos de identificación entregados al suscribirte, ya sea en oficina o vía envío certificado.'
#
# DOCUMENT251 = '¿Qué es un seguro de salud de alta deducibilidad? Es un seguro de salud que tiene un deducible alto, lo que puede resultar en primas más bajas.'
#
# DOCUMENT252 = '¿Qué es un seguro de vida a término renovable? Es un seguro de vida a término que puedes renovar al final del periodo sin necesidad de un nuevo examen médico.'
#
# DOCUMENT253 = '¿Qué es un seguro de vida con retorno de primas? Es un seguro de vida que devuelve las primas pagadas si el asegurado sobrevive al periodo de cobertura.'
#
# DOCUMENT254 = '¿Qué es un seguro de vida con ahorro? Es un seguro que combina la protección de vida con un componente de ahorro que acumula valor en efectivo.'
#
# DOCUMENT255 = '¿Qué es un seguro de automóvil de uso comercial? Es un seguro que cubre vehículos utilizados para fines comerciales o de negocio.'
#
# DOCUMENT256 = '¿Qué es un seguro de vida a plazo? Es un seguro que proporciona cobertura durante un periodo específico y paga un beneficio al fallecimiento.'
#
# DOCUMENT257 = '¿Qué debo hacer si mi aseguradora no responde a un reclamo? Escala tu caso a atención prioritaria si no obtienes respuesta adecuada.'
#
# DOCUMENT258 = '¿Qué debo hacer si quiero cancelar mi línea de crédito? Evalúa las opciones para cancelar líneas de crédito y elige la más adecuada.'
#
# DOCUMENT259 = '¿Qué debo hacer si quiero cancelar mi línea de crédito? Evalúa las opciones para cancelar líneas de crédito y elige la más adecuada.'
#
# DOCUMENT260 = '¿Qué debo hacer si quiero cancelar mi línea de crédito? Evalúa las opciones para cancelar líneas de crédito y elige la más adecuada.'
#
# DOCUMENT261 = '¿Qué alternativas tengo antes de cerrar definitivamente mi cuenta? Evalúa las opciones para retener tu cuenta y decide con tranquilidad.'
#
# DOCUMENT262 = '¿Qué cubre un seguro de responsabilidad civil? Explora los beneficios de un seguro de responsabilidad civil con tu asesor.'
#
# DOCUMENT263 = '¿Qué cubre un seguro de responsabilidad civil? Explora los beneficios de un seguro de responsabilidad civil con tu asesor.'
#
# DOCUMENT264 = '¿Qué cubre un seguro de responsabilidad civil? Explora los beneficios de un seguro de responsabilidad civil con tu asesor.'
#
# DOCUMENT265 = "¿Qué tipos de seguros de viaje ofrece el banco? Explora los seguros de viaje en la sección 'Protección al viajero' en tu app bancaria."
#
# DOCUMENT266 = "¿Qué tipos de seguros de viaje ofrece el banco? Explora los seguros de viaje en la sección 'Protección al viajero' en tu app bancaria."
#
# DOCUMENT267 = "¿Qué tipos de seguros de viaje ofrece el banco? Explora los seguros de viaje en la sección 'Protección al viajero' en tu app bancaria."
#
# DOCUMENT268 = '¿Cómo cancelo la suscripción a alertas bancarias? Gestiona la baja de alertas desde la configuración de notificaciones en tu app.'
#
# DOCUMENT269 = '¿Cómo cancelo la suscripción a alertas bancarias? Gestiona la baja de alertas desde la configuración de notificaciones en tu app.'
#
# DOCUMENT270 = '¿Cómo cancelo la suscripción a alertas bancarias? Gestiona la baja de alertas desde la configuración de notificaciones en tu app.'
#
# DOCUMENT271 = '¿Cómo renuncio a un seguro de vida contratado? Habla con el banco para finalizar tu seguro de vida sin contratiempos.'
#
# DOCUMENT272 = '¿Cómo renuncio a un seguro de vida contratado? Habla con el banco para finalizar tu seguro de vida sin contratiempos.'
#
# DOCUMENT273 = '¿Cómo renuncio a un seguro de vida contratado? Habla con el banco para finalizar tu seguro de vida sin contratiempos.'
#
# DOCUMENT274 = '¿Qué hago si necesito cerrar mi cuenta de manera urgente? Habla con tu banco para procesar un cierre urgente de tu cuenta.'
#
# DOCUMENT275 = '¿Puedo transferir el saldo restante de mi cuenta a un familiar? Habla con tu banco para transferir el saldo a un beneficiario autorizado.'
#
# DOCUMENT276 = '¿Cómo renuncio a un préstamo personal? Habla con un asesor para explorar las condiciones de renuncia a un préstamo.'
#
# DOCUMENT277 = '¿Cómo renuncio a un préstamo personal? Habla con un asesor para explorar las condiciones de renuncia a un préstamo.'
#
# DOCUMENT278 = '¿Cómo renuncio a un préstamo personal? Habla con un asesor para explorar las condiciones de renuncia a un préstamo.'
#
# DOCUMENT279 = '¿Qué debo hacer si deseo cambiar mi póliza actual? Habla con un asesor para modificar los términos de tu póliza según tus necesidades.'
#
# DOCUMENT280 = '¿Qué debo hacer si deseo cambiar mi póliza actual? Habla con un asesor para modificar los términos de tu póliza según tus necesidades.'
#
# DOCUMENT281 = '¿Qué debo hacer si deseo cambiar mi póliza actual? Habla con un asesor para modificar los términos de tu póliza según tus necesidades.'
#
# DOCUMENT282 = '¿Puedo transferir mi seguro de hogar a otra propiedad? Informa el cambio de propiedad al banco para evaluar el traslado del seguro.'
#
# DOCUMENT283 = '¿Puedo transferir mi seguro de hogar a otra propiedad? Informa el cambio de propiedad al banco para evaluar el traslado del seguro.'
#
# DOCUMENT284 = '¿Puedo transferir mi seguro de hogar a otra propiedad? Informa el cambio de propiedad al banco para evaluar el traslado del seguro.'
#
# DOCUMENT285 = '¿Qué pasos debo seguir para cancelar un producto financiero? Inicia el proceso de cancelación de un producto desde el menú de servicios.'
#
# DOCUMENT286 = '¿Qué pasos debo seguir para cancelar un producto financiero? Inicia el proceso de cancelación de un producto desde el menú de servicios.'
#
# DOCUMENT287 = '¿Qué pasos debo seguir para cancelar un producto financiero? Inicia el proceso de cancelación de un producto desde el menú de servicios.'
#
# DOCUMENT288 = '¿Puedo obtener un reembolso por un cobro erróneo? Inicia un reclamo desde la app o habla con un ejecutivo para resolverlo.'
#
# DOCUMENT289 = '¿Cómo puedo cancelar un préstamo? La cancelación de un préstamo requiere un proceso especifico dependiendo del contrato. Ponte en contacto con nuestro departamento de préstamos para más información.'
#
# DOCUMENT290 = '¿Qué cubre el seguro de vida que ofrecen? La cobertura de nuestro seguro de vida depende del plan seleccionado. Puede revisar la cobertura de los diferentes planes en nuestra web.'
#
# DOCUMENT291 = '¿Puedo reabrir mi cuenta bancaria después de haberla cerrado? La posibilidad de reabrir su cuenta bancaria dependerá de los motivos por los que fue cerrada.'
#
# DOCUMENT292 = '¿Qué comisiones se aplican a mi cuenta de cheques? Las comisiones aplicables a su cuenta de cheques se detallan en el contrato que firmó al abrirla. Puede consultarlas también en nuestra página web.'
#
# DOCUMENT293 = '¿Cuáles son las condiciones generales de los seguros que ofrecen? Las condiciones generales de nuestros seguros se encuentran disponibles en nuestra página web y también te las haremos llegar en tu póliza.'
#
# DOCUMENT294 = '¿Cómo solicito la baja de mi seguro de auto? Llama a atención al cliente para cancelar el seguro de auto sin problemas.'
#
# DOCUMENT295 = '¿Cómo solicito la baja de mi seguro de auto? Llama a atención al cliente para cancelar el seguro de auto sin problemas.'
#
# DOCUMENT296 = '¿Cómo solicito la baja de mi seguro de auto? Llama a atención al cliente para cancelar el seguro de auto sin problemas.'
#
# DOCUMENT297 = '¿Cómo solicito asistencia en carretera a través de mi seguro de auto? Llama a la línea de asistencia en carretera incluida en tu póliza de seguro.'
#
# DOCUMENT298 = '¿Qué documentos necesito para abrir una cuenta de ahorros? Lleva tu DNI, un recibo de luz o agua reciente y una sonrisa; ¡abrir una cuenta es sencillo!'
#
# DOCUMENT299 = '¿Qué documentos necesito para abrir una cuenta de ahorros? Lleva tu DNI, un recibo de luz o agua reciente y una sonrisa; ¡abrir una cuenta es sencillo!'
#
# DOCUMENT300 = '¿Qué documentos necesito para abrir una cuenta de ahorros? Lleva tu DNI, un recibo de luz o agua reciente y una sonrisa; ¡abrir una cuenta es sencillo!'
#
# DOCUMENT301 = '¿Qué requisitos necesito para contratar un seguro de vida? Lleva tu identificación oficial y pregunta por el seguro de vida que mejor se ajuste a ti.'
#
# DOCUMENT302 = '¿Qué requisitos necesito para contratar un seguro de vida? Lleva tu identificación oficial y pregunta por el seguro de vida que mejor se ajuste a ti.'
#
# DOCUMENT303 = '¿Qué requisitos necesito para contratar un seguro de vida? Lleva tu identificación oficial y pregunta por el seguro de vida que mejor se ajuste a ti.'
#
# DOCUMENT304 = '¿Hay algún costo asociado con el cierre de mi cuenta bancaria? Los costos asociados con el cierre de su cuenta bancaria dependerán de las condiciones de su contrato. Consulte en nuestra web.'
#
# DOCUMENT305 = '¿Cómo verifico los depósitos realizados a mi cuenta? Los depósitos se reflejan en la app casi al instante; ¡échale un vistazo!'
#
# DOCUMENT306 = '¿Cómo verifico los depósitos realizados a mi cuenta? Los depósitos se reflejan en la app casi al instante; ¡échale un vistazo!'
#
# DOCUMENT307 = '¿Cómo verifico los depósitos realizados a mi cuenta? Los depósitos se reflejan en la app casi al instante; ¡échale un vistazo!'
#
# DOCUMENT308 = '¿Qué documentos necesito para contratar un seguro de salud? Los documentos requeridos para contratar un seguro de salud varían. Consulte en nuestra web o en una sucursal.'
#
# DOCUMENT309 = '¿Qué documentos necesito para contratar un seguro? Los documentos requeridos varían según el tipo de seguro. Consulta nuestra página web o contacta a uno de nuestros ejecutivos para más información.'
#
# DOCUMENT310 = '¿Hay algún plazo para solicitar la renuncia a un producto financiero? Los plazos para renunciar a productos financieros varían según el producto. Revise las condiciones de su contrato o contáctese con atención al cliente.'
#
# DOCUMENT311 = '¿Existe algún plazo para renunciar a un producto financiero? Los plazos pueden variar dependiendo del tipo de producto. Te recomendamos consultar los términos y condiciones en tu contrato o con tu asesor financiero.'
#
# DOCUMENT312 = '¿Qué requisitos debo cumplir para solicitar una tarjeta de crédito? Los requisitos para solicitar una tarjeta de crédito varían según el tipo de tarjeta.  Consulte los detalles en nuestra página web o en una sucursal.'
#
# DOCUMENT313 = '¿Qué documentos necesito para contratar un seguro de vida? Necesitarás tu identificación, comprobante de ingresos y, en algunos casos, un examen médico.'
#
# DOCUMENT314 = '¿Cómo renuncio a una línea de crédito garantizada? Notifica a tu banco para gestionar la renuncia a la línea garantizada.'
#
# DOCUMENT315 = '¿Cómo notifico al banco de un siniestro en mi hogar? Notifica el siniestro enviando fotos y una breve descripción del incidente.'
#
# DOCUMENT316 = '¿Cómo notifico al banco de un siniestro en mi hogar? Notifica el siniestro enviando fotos y una breve descripción del incidente.'
#
# DOCUMENT317 = '¿Cómo notifico al banco de un siniestro en mi hogar? Notifica el siniestro enviando fotos y una breve descripción del incidente.'
#
# DOCUMENT318 = '¿Qué coberturas ofrece el seguro de auto? Nuestro seguro de auto cubre robo, accidentes y daños materiales, pero esto depende de cada plan y la póliza que contrates.'
#
# DOCUMENT319 = '¿Qué tipo de cuentas ofrecen? Ofrecemos cuentas corrientes, cuentas de ahorro y cuentas de inversión. Contacta a nuestros ejecutivos para más información.'
#
# DOCUMENT320 = '¿Qué tipos de seguros de vida ofrecen? Ofrecemos seguros de vida con diferentes coberturas y plazos para ajustarse a tus necesidades. Puedes obtener más información en nuestra página web o en cualquiera de nuestras sucursales.'
#
# DOCUMENT321 = '¿Qué tipos de seguros de vida ofrecen? Ofrecemos una variedad de seguros de vida, adaptados a sus necesidades.  Visite nuestra página web para obtener más información.'
#
# DOCUMENT322 = '¿Qué ocurre si no pago la prima de mi seguro a tiempo? Paga la prima dentro del plazo para evitar cargos adicionales o la cancelación del seguro.'
#
# DOCUMENT323 = '¿Qué ocurre si no pago la prima de mi seguro a tiempo? Paga la prima dentro del plazo para evitar cargos adicionales o la cancelación del seguro.'
#
# DOCUMENT324 = '¿Qué ocurre si no pago la prima de mi seguro a tiempo? Paga la prima dentro del plazo para evitar cargos adicionales o la cancelación del seguro.'
#
# DOCUMENT325 = '¿Puedo pagar mi prima de seguro en cuotas? Paga tu prima en cuotas cómodas, ajustadas a tu presupuesto.'
#
# DOCUMENT326 = '¿Puedo pagar mi prima de seguro en cuotas? Paga tu prima en cuotas cómodas, ajustadas a tu presupuesto.'
#
# DOCUMENT327 = '¿Puedo pagar mi prima de seguro en cuotas? Paga tu prima en cuotas cómodas, ajustadas a tu presupuesto.'
#
# DOCUMENT328 = '¿Qué requisitos necesito para abrir una cuenta corriente? Para abrir una cuenta corriente, necesitarás tu cédula de identidad, comprobante de domicilio y un comprobante de ingresos.'
#
# DOCUMENT329 = '¿Cómo puedo abrir una nueva cuenta corriente? Para abrir una cuenta corriente, puede visitar una de nuestras sucursales con su cédula de identidad y los documentos requeridos.'
#
# DOCUMENT330 = '¿Cómo puedo activar mi banca online? Para activar su banca online, siga las instrucciones que recibió en el correo electrónico o mensaje de texto que le enviamos al abrir su cuenta.'
#
# DOCUMENT331 = "¿Cómo cambio mi clave de acceso a la banca online? Para cambiar su clave, acceda a la sección 'Seguridad' en nuestra página web o aplicación móvil y siga las instrucciones."
#
# DOCUMENT332 = '¿Cómo puedo cambiar mi correo electrónico registrado en el banco? Para cambiar su correo electrónico, deberá visitar una sucursal con su documentación.'
#
# ...
#
# DOCUMENT933 = '¿Cómo puedo obtener un seguro de responsabilidad civil personal? Puedes obtener un seguro de responsabilidad civil personal a través de la banca en línea o contactando a un agente.'
#
# DOCUMENT934 = '¿Qué cubre un seguro de salud para maternidad? Cubre gastos relacionados con el embarazo, el parto y cuidados postnatales.'
#
# DOCUMENT935 = '¿Cómo puedo presentar un reclamo por daños en mi hogar? Debes comunicarte con tu aseguradora y proporcionar la información necesaria sobre los daños.'
#
# DOCUMENT936 = '¿Qué es un seguro de vida a término renovable? Es un seguro de vida a término que puedes renovar al final del periodo sin necesidad de un nuevo examen médico.'
#
# DOCUMENT937 = '¿Cómo puedo obtener un seguro de automóvil para jóvenes conductores? Puedes obtener un seguro de automóvil para jóvenes conductores a través de la banca en línea o contactando a un asesor.'
#
# DOCUMENT938 = '¿Qué es un seguro de salud de alta deducibilidad? Es un seguro de salud que tiene un deducible alto, lo que puede resultar en primas más bajas.'
#
# DOCUMENT939 = '¿Cómo puedo cambiar mi póliza de seguro de automóvil? Puedes cambiar tu póliza de seguro de automóvil contactando a tu aseguradora.'
#
# DOCUMENT940 = '¿Qué cubre un seguro de vida accidental? Cubre el fallecimiento accidental y puede pagar un beneficio adicional.'
#
# DOCUMENT941 = '¿Cómo puedo obtener un seguro de salud para personas mayores? Puedes obtener un seguro de salud para personas mayores a través de la banca en línea o contactando a un agente.'
#
# DOCUMENT942 = '¿Qué es un seguro de vida con retorno de primas? Es un seguro de vida que devuelve las primas pagadas si el asegurado sobrevive al periodo de cobertura.'
#
# DOCUMENT943 = '¿Cómo puedo cancelar un seguro de automóvil? Debes comunicarte con tu aseguradora para iniciar el proceso de cancelación.'
#
# DOCUMENT944 = '¿Qué cubre un seguro de salud para tratamientos médicos? Cubre gastos médicos, hospitalarios y tratamientos necesarios según la póliza.'
#
# DOCUMENT945 = '¿Cómo puedo obtener un seguro de vida para menores de edad? Puedes obtener un seguro de vida para menores contactando a un agente de seguros.'
#
# DOCUMENT946 = '¿Qué es un seguro de automóvil de uso comercial? Es un seguro que cubre vehículos utilizados para fines comerciales o de negocio.'
#
# DOCUMENT947 = '¿Cómo puedo cambiar mi cobertura de seguro de hogar? Puedes cambiar tu cobertura de seguro de hogar contactando a tu aseguradora.'
#
# DOCUMENT948 = '¿Qué cubre un seguro de salud para emergencias? Cubre gastos médicos por emergencias, incluyendo hospitalización y tratamientos urgentes.'
#
# DOCUMENT949 = '¿Cómo puedo obtener un seguro de vida con beneficios por invalidez? Puedes obtener un seguro de vida con beneficios por invalidez a través de la banca en línea o contactando a un agente.'
#
# DOCUMENT950 = '¿Qué es un seguro de automóvil a todo riesgo? Cubre daños a tu vehículo y a terceros, así como robos y vandalismo.'
#
# DOCUMENT951 = '¿Cómo puedo consultar mi saldo bancario? Puedes consultar tu saldo a través de la app móvil del banco o en un cajero automático.'
#
# DOCUMENT952 = "¿Qué debo hacer para generar una cartola bancaria? Para generar una cartola bancaria, ingresa a tu banca en línea y selecciona 'Estado de cuenta'."
#
# DOCUMENT953 = "¿Cómo cambio mi clave de acceso a la banca en línea? Ingresa a tu banca en línea, selecciona 'Seguridad' y sigue las instrucciones para cambiar tu clave."
#
# DOCUMENT954 = '¿Cuáles son los pasos para realizar una transferencia internacional? Dirígete a la sección de transferencias internacionales y completa la información requerida.'
#
# DOCUMENT955 = '¿Cómo puedo abrir una nueva cuenta corriente? Acude a una sucursal o realiza el trámite a través de la app del banco.'
#
# DOCUMENT956 = '¿Qué documentos necesito para abrir una cuenta de ahorros? Necesitas tu documento de identidad, comprobante de domicilio y una cantidad mínima de apertura.'
#
# DOCUMENT957 = '¿Cómo activo mi tarjeta de débito? Puedes activarla llamando al servicio al cliente o mediante la app móvil.'
#
# DOCUMENT958 = "¿Cómo puedo solicitar un estado de cuenta mensual? Selecciona 'Estado de cuenta' en tu banca en línea para obtener el documento."
#
# DOCUMENT959 = '¿Qué debo hacer si olvidé mi clave de acceso? Contacta a tu banco para restablecer tu clave mediante verificación de identidad.'
#
# DOCUMENT960 = '¿Cómo puedo bloquear mi tarjeta por pérdida o robo? Llama inmediatamente al banco o utiliza la opción de bloqueo en la app móvil.'
#
# DOCUMENT961 = '¿Cómo consulto las tasas de interés actuales? Consulta las tasas en la página web del banco o contacta a tu ejecutivo de cuenta.'
#
# DOCUMENT962 = '¿Qué pasos debo seguir para configurar un débito automático? Accede a la configuración de pagos automáticos en tu banca en línea.'
#
# DOCUMENT963 = '¿Cómo puedo cambiar mi dirección registrada en el banco? Contacta al banco con un comprobante de domicilio actualizado para hacer el cambio.'
#
# DOCUMENT964 = '¿Cómo solicito un préstamo personal? Rellena una solicitud en línea o acude a una sucursal para iniciar el proceso.'
#
# DOCUMENT965 = "¿Puedo programar transferencias recurrentes? En la app móvil, busca 'Transferencias programadas' y sigue los pasos."
#
# DOCUMENT966 = "¿Cómo verifico los movimientos recientes en mi cuenta? Revisa la sección 'Movimientos recientes' en la banca en línea o en la app."
#
# DOCUMENT967 = '¿Qué hago si una transacción no autorizada aparece en mi cuenta? Reporta la transacción al banco para iniciar una investigación.'
#
# DOCUMENT968 = '¿Cómo agrego beneficiarios a mi cuenta bancaria? Añade beneficiarios en la sección correspondiente de tu banca en línea.'
#
# DOCUMENT969 = '¿Dónde puedo encontrar el SWIFT de mi banco? Busca el código SWIFT en la sección de información internacional del banco.'
#
# DOCUMENT970 = '¿Cómo solicito una copia de un cheque cobrado? Solicita una copia llamando al servicio al cliente o visitando una sucursal.'
#
# DOCUMENT971 = '¿Qué requisitos necesito para solicitar una línea de crédito? Consulta con tu banco los documentos necesarios y las condiciones para una línea de crédito.'
#
# DOCUMENT972 = "¿Cómo solicito una tarjeta de crédito adicional? Utiliza la opción de 'Tarjetas adicionales' en la banca en línea para solicitarla."
#
# DOCUMENT973 = '¿Cómo habilito mi tarjeta para compras internacionales? Activa la función de compras internacionales en la configuración de tu tarjeta.'
#
# DOCUMENT974 = "¿Cómo configuro notificaciones por SMS de movimientos bancarios? Configura notificaciones en la sección 'Alertas' de la banca en línea."
#
# DOCUMENT975 = '¿Qué hago si mi tarjeta fue retenida por un cajero automático? Contacta al banco para informar la retención y solicitar la recuperación.'
#
# DOCUMENT976 = "¿Cómo verifico los depósitos realizados a mi cuenta? Busca 'Depósitos' en la app o en la banca en línea para verificarlos."
#
# DOCUMENT977 = '¿Cómo obtengo el número IBAN de mi cuenta? Puedes encontrar tu IBAN en tu estado de cuenta o en la app móvil.'
#
# DOCUMENT978 = "¿Cómo actualizo mis datos personales en la banca en línea? Selecciona 'Actualizar datos' en tu perfil dentro de la banca en línea."
#
# DOCUMENT979 = '¿Cómo consulto el límite de crédito de mi tarjeta? Consulta el límite en la sección de detalles de tu tarjeta en la app.'
#
# DOCUMENT980 = '¿Qué debo hacer para cerrar una cuenta bancaria inactiva? Contacta al banco para iniciar el proceso de cierre de la cuenta.'
#
# DOCUMENT981 = '¿Cómo cotizo un seguro para mi vehículo? Visita la sección de seguros en la página del banco y utiliza la herramienta de cotización.'
#
# DOCUMENT982 = '¿Qué requisitos necesito para contratar un seguro de vida? Generalmente necesitas un documento de identidad, comprobante de domicilio y completar una solicitud.'
#
# DOCUMENT983 = '¿Cómo puedo cancelar un seguro de hogar? Contacta al banco para iniciar el proceso de cancelación del seguro.'
#
# DOCUMENT984 = '¿Qué tipos de seguros de viaje ofrece el banco? Consulta las opciones de seguros de viaje en el sitio web del banco o llama a su línea de atención.'
#
# DOCUMENT985 = '¿Cómo puedo renovar mi seguro de salud? Renueva tu seguro en la sección de pólizas dentro de la app o contacta a un asesor.'
#
# DOCUMENT986 = '¿Qué cubre el seguro contra accidentes personales? Cubre lesiones corporales causadas por accidentes imprevistos.'
#
# DOCUMENT987 = '¿Cuáles son los pasos para reclamar un seguro de vida? Completa el formulario de reclamación y presenta los documentos requeridos al banco.'
#
# DOCUMENT988 = '¿Puedo transferir mi seguro de hogar a otra propiedad? Informa al banco de la transferencia de propiedad para evaluar la transferencia del seguro.'
#
# DOCUMENT989 = '¿Cómo calculo la prima de un seguro para mi auto? Accede a la calculadora de primas en la página del banco o contacta al asesor de seguros.'
#
# DOCUMENT990 = '¿Cómo obtengo el certificado de cobertura de mi seguro? Solicita el certificado en la sección de seguros de tu banca en línea.'
#
# DOCUMENT991 = '¿Qué debo hacer si deseo cambiar mi póliza actual? Contacta al banco para discutir las opciones de cambio de tu póliza.'
#
# DOCUMENT992 = '¿Cómo notifico al banco de un siniestro en mi hogar? Informa el siniestro al banco con fotos y documentos de soporte.'
#
# DOCUMENT993 = '¿Qué documentación necesito para un seguro de viaje? Revisa los requisitos en la sección de seguros de viaje en la página web del banco.'
#
# DOCUMENT994 = '¿Cuáles son las exclusiones típicas en un seguro de vida? Consulta las exclusiones detalladas en el contrato de tu seguro.'
#
# DOCUMENT995 = '¿Puedo pagar mi prima de seguro en cuotas? Confirma las opciones de pago en cuotas con tu asesor bancario.'
#
# DOCUMENT996 = '¿Cómo contrato un seguro de gastos médicos mayores? Completa la solicitud de contratación en línea o en una sucursal.'
#
# DOCUMENT997 = '¿Cómo sé si mi seguro cubre daños por desastres naturales? Revisa las coberturas específicas en la póliza o contacta a tu asesor.'
#
# DOCUMENT998 = '¿Qué beneficios tiene un seguro de educación? Consulta con tu banco los detalles del seguro de educación.'
#
# DOCUMENT999 = '¿Puedo incluir a mi cónyuge en mi póliza de salud? Solicita la inclusión presentando los documentos de tu cónyuge al banco.'
#
# DOCUMENT1000 = '¿Cómo modifico los beneficiarios de mi seguro de vida? Accede a tu perfil de cliente y actualiza los beneficiarios en la sección de seguros.'
#
# DOCUMENT1001 = '¿Qué pasos debo seguir para cancelar un seguro de auto? Contacta al banco para iniciar la cancelación de tu póliza de auto.'
#
# DOCUMENT1002 = '¿Cómo cotizo un seguro para mi negocio? Accede a la sección de negocios en el portal de seguros del banco.'
#
# DOCUMENT1003 = '¿Puedo combinar diferentes seguros en una sola póliza? Confirma la disponibilidad de pólizas combinadas con tu asesor bancario.'
#
# DOCUMENT1004 = '¿Cómo actualizo mi dirección en mi seguro de hogar? Actualiza tu dirección en la sección de perfil dentro de la banca en línea.'
#
# DOCUMENT1005 = '¿Qué ocurre si no pago la prima de mi seguro a tiempo? El banco puede cancelar el seguro si no pagas en el plazo establecido.'
#
# DOCUMENT1006 = '¿Cómo agrego cobertura adicional a mi seguro actual? Contacta a tu banco para añadir cobertura adicional a tu seguro.'
#
# DOCUMENT1007 = '¿Qué cubre un seguro para dispositivos electrónicos? Consulta las condiciones de cobertura en la sección de dispositivos electrónicos.'
#
# DOCUMENT1008 = '¿Puedo asegurar mi auto si no tengo licencia? Verifica las condiciones para asegurar un auto sin licencia en tu banco.'
#
# DOCUMENT1009 = '¿Cómo solicito un reembolso por gastos médicos cubiertos? Presenta los recibos y la documentación para solicitar el reembolso.'
#
# DOCUMENT1010 = '¿Qué cubre un seguro de responsabilidad civil? Consulta los detalles de tu cobertura de responsabilidad civil en tu contrato.'
#
# DOCUMENT1011 = '¿Cómo cierro mi cuenta bancaria? Acude a una sucursal o solicita el cierre mediante la banca en línea.'
#
# DOCUMENT1012 = '¿Qué debo hacer para cancelar mi tarjeta de crédito? Contacta al banco para iniciar la cancelación de tu tarjeta de crédito.'
#
# DOCUMENT1013 = '¿Cómo renuncio a un préstamo personal? Consulta con el banco las condiciones para renunciar al préstamo.'
#
# DOCUMENT1014 = '¿Qué pasos debo seguir para cerrar mi cuenta de ahorros? Visita una sucursal para firmar la solicitud de cierre.'
#
# DOCUMENT1015 = '¿Cuáles son los requisitos para cancelar un seguro contratado? Proporciona una carta firmada para cancelar el seguro.'
#
# DOCUMENT1016 = '¿Cómo renuncio a un servicio de débito automático? Accede a la configuración de débito automático en la app y cancela el servicio.'
#
# DOCUMENT1017 = '¿Qué ocurre con los saldos pendientes si cierro mi cuenta? Consulta con el banco las opciones para saldar los pendientes.'
#
# DOCUMENT1018 = '¿Cómo cancelo una transferencia recurrente programada? Desactiva las transferencias recurrentes en la configuración de pagos.'
#
# DOCUMENT1019 = '¿Qué debo hacer para cerrar una cuenta conjunta? Ambos titulares deben acudir al banco para cerrar la cuenta conjunta.'
#
# DOCUMENT1020 = '¿Cómo cancelo la suscripción a alertas bancarias? Accede a la sección de alertas en tu app y desactiva la suscripción.'
#
# DOCUMENT1021 = '¿Qué pasos debo seguir para cancelar un producto financiero? Contacta al banco para discutir los pasos de cancelación del producto.'
#
# DOCUMENT1022 = '¿Cómo cierro mi cuenta si estoy fuera del país? Envía una solicitud por escrito o usa la banca en línea si estás en el extranjero.'
#
# DOCUMENT1023 = '¿Puedo cerrar mi cuenta sin acudir a la sucursal? Confirma si tu banco permite el cierre en línea revisando su página web.'
#
# DOCUMENT1024 = '¿Cómo renuncio a un seguro de vida contratado? Solicita el cierre del seguro proporcionando tus datos al banco.'
#
# DOCUMENT1025 = '¿Qué debo hacer si quiero cancelar mi línea de crédito? Contacta a tu banco para evaluar las condiciones de cancelación de la línea.'
#
# DOCUMENT1026 = '¿Cómo solicito el cierre de una cuenta por fallecimiento del titular? Presenta el certificado de defunción y los documentos legales requeridos.'
#
# DOCUMENT1027 = '¿Cuánto tiempo toma procesar el cierre de una cuenta bancaria? El tiempo depende del banco, pero suele tardar entre 5 y 10 días hábiles.'
#
# DOCUMENT1028 = '¿Qué documentos necesito para cancelar una cuenta de inversión? Presenta una solicitud y documentos para cancelar tu cuenta de inversión.'
#
# DOCUMENT1029 = '¿Cómo renuncio a mi membresía en el banco? Envía una carta al banco indicando que deseas renunciar a la membresía.'
#
# DOCUMENT1030 = '¿Qué ocurre con mis puntos de recompensa al cerrar una cuenta? Confirma con el banco si puedes redimir los puntos antes del cierre.'
#
# DOCUMENT1031 = '¿Cómo solicito la baja de mi seguro de auto? Completa una solicitud de baja y presenta los documentos del seguro.'
#
# DOCUMENT1032 = '¿Qué pasa con mis débitos automáticos al cerrar mi cuenta? Cancela los débitos automáticos antes de iniciar el proceso de cierre.'
#
# DOCUMENT1033 = '¿Cómo cancelo un crédito hipotecario? Proporciona los documentos de la hipoteca para cancelar el crédito.'
#
# DOCUMENT1034 = '¿Puedo cerrar mi cuenta con saldo negativo? Consulta con el banco si ofrecen opciones para resolver el saldo negativo.'
#
# DOCUMENT1035 = '¿Cómo obtengo una confirmación del cierre de mi cuenta? Solicita una carta de confirmación al cerrar la cuenta.'
#
# DOCUMENT1036 = '¿Qué ocurre con los cheques pendientes al cerrar mi cuenta? Consulta con el banco el manejo de cheques pendientes antes del cierre.'
#
# DOCUMENT1037 = '¿Cómo renuncio a una cuenta empresarial? Sigue los pasos indicados por el banco para cerrar una cuenta empresarial.'
#
# DOCUMENT1038 = '¿Qué pasa con mis inversiones al cerrar mi cuenta? Consulta las políticas del banco sobre inversiones al cerrar cuentas.'
#
# DOCUMENT1039 = '¿Cómo cierro una cuenta con acceso restringido? Proporciona los documentos necesarios para eliminar las restricciones.'
#
# DOCUMENT1040 = '¿Qué debo hacer si el banco rechaza mi solicitud de cierre? Contacta al banco para resolver las objeciones y repetir el proceso.'

# %% [markdown]
# # API Keys

# %%
import openai
import os

# Configurar la clave de API de OpenAI
openai.api_key = '###################' # Anonimizada
os.environ["OPENAI_API_KEY"] = openai.api_key

openai.api_key = os.environ.get('OPENAI_API_KEY')
client = openai.OpenAI()
answer = client.chat.completions.create

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist

def get_embedding(text, model="text-embedding-ada-002"):
    """
    Genera un embedding vectorial para un texto utilizando un modelo de embeddings.

    Args:
        text (str): Texto de entrada para el cual se generará el embedding.
        model (str): Nombre del modelo de OpenAI utilizado para generar el embedding.
                     Por defecto, utiliza el modelo "text-embedding-ada-002".

    Returns:
        list: Un vector (embedding) de alta dimensionalidad que representa la semántica del texto.
    """

    text = text.replace("\n", " ")

    response = client.embeddings.create(input=[text], model=model)

    return response.data[0].embedding

embedding_model = "text-embedding-ada-002"

# Ensure 'documents' is a DataFrame or Series before applying the function
documents = data["Pregunta_respuesta"]  # This assumes 'data' is your DataFrame
documents = documents.to_frame()  # If 'documents' is a Series, convert it to a DataFrame
documents["embedding"] = documents['Pregunta_respuesta'].apply(lambda x: get_embedding(x, model=embedding_model))

# Ensure there are embeddings to concatenate
if len(documents.embedding.values) > 0:
    matrix = np.vstack(documents.embedding.values)
else:
    matrix = np.array([])

# %%
documents.head()
# Out:
#                                   Pregunta_respuesta  \
# 0  ¿Cómo cambio mi clave de acceso a la banca en ...
# 1  ¿Cómo habilito mi tarjeta para compras interna...
# 2  ¿Cómo activo la cobertura inmediata en mi segu...
# 3  ¿Cómo activo mi tarjeta de débito? Actívala di...
# 4  ¿Cómo actualizo mi dirección en mi seguro de h...
#
#                                            embedding
# 0  [-0.015041896142065525, -0.022150302305817604,...
# 1  [-0.004591276869177818, -0.003662846749648452,...
# 2  [-0.01625330187380314, -0.010508600622415543, ...
# 3  [-0.030755281448364258, -0.010065251030027866,...
# 4  [-0.017373504117131233, -0.0004793013795278966...

# %%
# Exportar embeddings
documents.to_excel('documents.xlsx')

# %%
import ast
import chromadb
from chromadb.config import Settings
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

# Crear la base de datos Chroma
def create_chroma_db(documents, collection_name):
    """
    Crea una base de datos vectorial en Chroma a partir de un conjunto de documentos y sus embeddings.

    Args:
        documents (pandas.DataFrame): Un DataFrame que contiene los documentos y sus embeddings precomputados.
                                      Debe incluir las columnas:
                                      - 'Pregunta_respuesta': Texto unificado del documento.
                                      - 'embedding': Embedding asociado al documento.
        collection_name (str): Nombre de la colección que se creará en ChromaDB.

    Returns:
        chromadb.Collection: La colección creada en ChromaDB que contiene los documentos y sus embeddings.

    """
    chroma_client = chromadb.Client()
    embedding_function = OpenAIEmbeddingFunction(api_key=openai.api_key)  # Usar la API de OpenAI
    db = chroma_client.create_collection(collection_name, embedding_function=embedding_function)

    # Agregar los documentos y embeddings a la colección
    for i, row in documents.iterrows():
        # Check if the embedding is already a list
        if isinstance(row['embedding'], list):
            embedding = row['embedding']
        else:
            # If not a list, try to convert it using ast.literal_eval
            try:
                embedding = ast.literal_eval(row['embedding'])
            except (SyntaxError, ValueError):
                # If conversion fails, print a warning and skip the row
                print(f"Warning: Could not convert embedding for row {i}. Skipping.")
                continue
        db.add(
            documents=[row["Pregunta_respuesta"]],
            embeddings=[embedding],  # Embeddings precomputados
            ids=[str(i)]
        )

    print(f"Chroma collection '{collection_name}' created with {len(documents)} documents.")
    return db

# %%
# Función para realizar consultas en la base de datos Chroma
def query_chroma(query, db, n_results=1):
    """
    Realiza una consulta a la base de datos Chroma para encontrar el texto más relevante.

    Args:
        query (str): Texto de consulta.
        db (chromadb.Collection): Colección de Chroma donde buscar.
        n_results (int): Número de resultados más relevantes a devolver.

    Returns:
        list: Lista de los textos más relevantes encontrados.
    """
    results = db.query(query_texts=[query], n_results=n_results)
    return results["documents"][0] if "documents" in results and results["documents"] else []

# %%
# Crear la base de datos en Chroma
chroma_collection = create_chroma_db(documents,"prueba.autogestion")
# Out:
# Chroma collection 'prueba.autogestion' created with 1041 documents.

# %%
# Consultar la base de datos con un query
query = "¿Cómo consultar el saldo de mi cuenta?"
relevant_passages = query_chroma(query, chroma_collection, n_results=1)

# Mostrar los resultados
print("Relevant passage(s):")
for passage in relevant_passages:
  print(passage)
# Out:
# Relevant passage(s):
# ¿Cómo puedo consultar el saldo de mi cuenta? Puedes consultar el saldo de tu cuenta a través de la banca en línea, la aplicación móvil o en un cajero automático.

# %% [markdown]
# # Integración LLM

# %%
def query_prompt(query, relevant_passage):
    """
    Crea un prompt para el LLM utilizando la consulta del usuario y un documento relevante.

    Args:
        query (str): Consulta realizada por el usuario.
        relevant_passage (str): Documento relevante recuperado de la base de datos.

    Returns:
        str: Prompt contextualizado para el LLM.
    """
    # Limpieza básica del documento relevante
    escaped_passage = relevant_passage.replace("'", "").replace('"', "").replace("\n", " ")

    # Construcción del prompt
    prompt = (f"""
    Eres un asistente útil e informativo que responde preguntas basándote en el texto proporcionado en el pasaje de referencia incluido a continuación.
    Asegúrate de responder de manera completa, siendo comprensivo y proporcionando toda la información de contexto relevante.
    Sin embargo, estás hablando con una audiencia no técnica, así que desglosa los conceptos complicados y utiliza recursos amigable.
    Si la pregunta no es relevante para la respuesta, puedes derivar la respuesta hacia un ejecutivo u oficina de atención.

    PREGUNTA: '{query}'
    PASAJE: '{escaped_passage}'

    RESPUESTA:
    """)
    return prompt

# %%
def generate_response(query, db, model):
    """
    Genera una respuesta personalizada utilizando el LLM y un documento relevante de ChromaDB.

    Args:
        query (str): Consulta realizada por el usuario.
        db: Objeto de la colección ChromaDB.
        model: Objeto del modelo generativo (e.g., Gemini o GPT).

    Returns:
        str: Respuesta generada por el LLM.
    """
    # Recuperar el pasaje relevante desde ChromaDB
    relevant_passage = db.query(query_texts=[query], n_results=1)['documents'][0][0]

    # Crear el prompt contextualizado
    prompt = query_prompt(query, relevant_passage)

    # Generar la respuesta utilizando el modelo generativo
    response = model.generate_content(prompt)

    return response.text

# %%
# Simular una consulta del usuario
query = "¿Cómo puedo consultar mi saldo bancario?"

# Obtener el modelo generativo (Gemini, GPT, etc.)
model = genai.GenerativeModel('gemini-1.5-flash-latest')

# Generar la respuesta
response = generate_response(query, chroma_collection, model)

# Mostrar la respuesta generada
print("Respuesta del LLM:")
print(response)
# Out:
# Respuesta del LLM:
# Para consultar tu saldo bancario, tienes dos opciones muy sencillas:
#
# 1. **A través de la aplicación móvil de tu banco:**  Si tu banco tiene una aplicación para teléfonos inteligentes (como un celular o tablet),  descarga la app y regístrate.  Normalmente, necesitarás tu número de cuenta y alguna otra información de seguridad (como una contraseña o un PIN).  Una vez que inicies sesión,  tu saldo debería aparecer inmediatamente en la pantalla principal.  Es rápido, fácil y puedes hacerlo desde cualquier lugar con conexión a internet.
#
# 2. **En un cajero automático (ATM):**  Visita cualquier cajero automático de tu banco. Introduce tu tarjeta de débito y tu PIN.  Generalmente, hay una opción en el menú principal para consultar tu saldo.  Selecciona esa opción y el cajero automático te mostrará tu saldo actual en la pantalla.  Esta opción es útil si no tienes acceso a internet o prefieres no usar tu teléfono móvil.
#
#
# Si tienes problemas con cualquiera de estos métodos, te recomiendo que contactes directamente al servicio de atención al cliente de tu banco.  Ellos podrán ayudarte con cualquier inconveniente que tengas.
